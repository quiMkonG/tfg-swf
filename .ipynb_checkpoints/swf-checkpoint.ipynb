# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,10))

ax = plt.axes(projection='3d')
 # plot the point (2,3,4) on the figure

v2 = np.loadtxt('vertices_2.txt')

for i in range(np.size(v2[0])):
    print(f'The point {i} is {v2[0,i]} , {v2[1,i]} , {v2[2,i]}')
    ax.scatter(v2[0,i],v2[1,i],v2[2,i])
    
plt.show()
# Out:
# The point 0 is 1.0 , 0.0 , 0.0
# The point 1 is -1.0 , 0.0 , 0.0
# The point 2 is 0.0 , 1.0 , 0.0
# The point 3 is 0.0 , -1.0 , 0.0
# The point 4 is 0.0 , 0.0 , 1.0
# The point 5 is 0.0 , 0.0 , -1.0
# The point 6 is 0.7071068 , 0.7071068 , 0.0
# The point 7 is -0.7071068 , 0.7071068 , 0.0
# The point 8 is 0.7071068 , -0.7071068 , 0.0
# The point 9 is -0.7071068 , -0.7071068 , 0.0
# The point 10 is 0.7071068 , 0.0 , 0.7071068
# The point 11 is -0.7071068 , 0.0 , 0.7071068
# The point 12 is 0.0 , 0.7071068 , 0.7071068
# The point 13 is 0.0 , -0.7071068 , 0.7071068
# The point 14 is 0.7071068 , 0.0 , -0.7071068
# The point 15 is -0.7071068 , 0.0 , -0.7071068
# The point 16 is 0.0 , 0.7071068 , -0.7071068
# The point 17 is 0.0 , -0.7071068 , -0.7071068
# The point 18 is 0.9546413 , 0.2977582 , 0.0
# The point 19 is 0.2977582 , 0.9546413 , 0.0
# The point 20 is -0.9546413 , 0.2977582 , 0.0
# The point 21 is -0.2977582 , 0.9546413 , 0.0
# The point 22 is 0.9546413 , -0.2977582 , 0.0
# ...
